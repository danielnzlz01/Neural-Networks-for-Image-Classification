# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import pandas as pd
from keras.utils import image_dataset_from_directory, plot_model
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, AveragePooling2D, Dropout, Flatten
from keras.metrics import SparseTopKCategoricalAccuracy
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
img_dims = (256, 256)
batch_size = 32
n_inputs = img_dims[0] * img_dims[1] * 3

train = image_dataset_from_directory(
    directory='cards/train',
    image_size=img_dims,
    batch_size=batch_size
)

val = image_dataset_from_directory(
    directory='cards/valid',
    image_size=img_dims,
    batch_size=batch_size
)

test = image_dataset_from_directory(
    directory='cards/test',
    image_size=img_dims,
    batch_size=batch_size
)
# Out:
# Found 7624 files belonging to 53 classes.
# Found 265 files belonging to 53 classes.
# Found 265 files belonging to 53 classes.

# %%
model6 = Sequential()


model6.add(Conv2D(
    filters=32,
    kernel_size=(4, 4),
    activation='relu',
    input_shape=img_dims + (3,),
    data_format="channels_last"
))


model6.add(Conv2D(
    filters=32,
    kernel_size=(4, 4),
    activation='relu'
))
model6.add(MaxPooling2D(pool_size=(2, 2)))
model6.add(Dropout(rate=0.2))


model6.add(Conv2D(
    filters=64, 
    kernel_size=(4, 4),
    activation='relu'
))
model6.add(MaxPooling2D(pool_size=(3, 3)))
model6.add(Dropout(rate=0.2))


model6.add(Conv2D(
    filters=128, 
    kernel_size=(4, 4),
    activation='relu'
))
model6.add(MaxPooling2D(pool_size=(4, 4)))
model6.add(Dropout(rate=0.2))


model6.add(Flatten())
model6.add(Dense(512, activation='relu'))
model6.add(Dense(128, activation='relu'))
model6.add(Dense(53, activation='softmax'))

model6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 253, 253, 32)      1568
#
#  conv2d_1 (Conv2D)           (None, 250, 250, 32)      16416
#
#  max_pooling2d (MaxPooling2D  (None, 125, 125, 32)     0
#  )
#
#  dropout (Dropout)           (None, 125, 125, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 122, 122, 64)      32832
#
#  max_pooling2d_1 (MaxPooling  (None, 40, 40, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 40, 40, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 37, 37, 128)       131200
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 9, 9, 128)         0
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 512)               5308928
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 53)                6837
#
# =================================================================
# Total params: 5,563,445
# Trainable params: 5,563,445
# Non-trainable params: 0
# _________________________________________________________________

# %%
model6.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', SparseTopKCategoricalAccuracy(k=3, name = 'Top3')]
)

callbacks = [
    EarlyStopping(
        monitor="accuracy",
        min_delta=1e-4,
        patience=3,
        verbose=1,
    )
]

history6 = model6.fit(
    train,
    validation_data = val,
    epochs = 10000,
    callbacks = callbacks
)
# Out:
# Epoch 1/10000
# 239/239 [==============================] - 96s 346ms/step - loss: 9.0916 - accuracy: 0.0450 - Top3: 0.1064 - val_loss: 3.5975 - val_accuracy: 0.1208 - val_Top3: 0.2566
# Epoch 2/10000
# 239/239 [==============================] - 42s 174ms/step - loss: 2.9448 - accuracy: 0.2580 - Top3: 0.4304 - val_loss: 1.8209 - val_accuracy: 0.4830 - val_Top3: 0.7698
# Epoch 3/10000
# 239/239 [==============================] - 43s 177ms/step - loss: 1.8431 - accuracy: 0.4984 - Top3: 0.7020 - val_loss: 1.0662 - val_accuracy: 0.6981 - val_Top3: 0.8755
# Epoch 4/10000
# 239/239 [==============================] - 40s 167ms/step - loss: 1.3769 - accuracy: 0.6191 - Top3: 0.7886 - val_loss: 0.8868 - val_accuracy: 0.7547 - val_Top3: 0.8830
# Epoch 5/10000
# 239/239 [==============================] - 39s 162ms/step - loss: 1.0703 - accuracy: 0.6941 - Top3: 0.8490 - val_loss: 0.8744 - val_accuracy: 0.7623 - val_Top3: 0.8906
# Epoch 6/10000
# 239/239 [==============================] - 39s 163ms/step - loss: 0.8484 - accuracy: 0.7554 - Top3: 0.8909 - val_loss: 0.8631 - val_accuracy: 0.7736 - val_Top3: 0.8792
# Epoch 7/10000
# 239/239 [==============================] - 41s 172ms/step - loss: 0.6862 - accuracy: 0.7998 - Top3: 0.9220 - val_loss: 0.8236 - val_accuracy: 0.7925 - val_Top3: 0.9057
# Epoch 8/10000
# 239/239 [==============================] - 41s 170ms/step - loss: 0.5700 - accuracy: 0.8448 - Top3: 0.9436 - val_loss: 0.8823 - val_accuracy: 0.8075 - val_Top3: 0.8943
# Epoch 9/10000
# 239/239 [==============================] - 41s 170ms/step - loss: 0.4817 - accuracy: 0.8670 - Top3: 0.9605 - val_loss: 0.8921 - val_accuracy: 0.8113 - val_Top3: 0.8906
# Epoch 10/10000
# 239/239 [==============================] - 41s 171ms/step - loss: 0.4220 - accuracy: 0.8860 - Top3: 0.9680 - val_loss: 0.8650 - val_accuracy: 0.8151 - val_Top3: 0.8981
# Epoch 11/10000
# 239/239 [==============================] - 41s 172ms/step - loss: 0.3433 - accuracy: 0.9083 - Top3: 0.9798 - val_loss: 0.8119 - val_accuracy: 0.8377 - val_Top3: 0.9170
# Epoch 12/10000
# 239/239 [==============================] - 41s 170ms/step - loss: 0.3078 - accuracy: 0.9161 - Top3: 0.9829 - val_loss: 0.8490 - val_accuracy: 0.8075 - val_Top3: 0.8943
# Epoch 13/10000
# 239/239 [==============================] - 46s 189ms/step - loss: 0.2771 - accuracy: 0.9269 - Top3: 0.9848 - val_loss: 0.8787 - val_accuracy: 0.8415 - val_Top3: 0.9132
# Epoch 14/10000
# 239/239 [==============================] - 39s 160ms/step - loss: 0.2625 - accuracy: 0.9256 - Top3: 0.9865 - val_loss: 1.0191 - val_accuracy: 0.7925 - val_Top3: 0.9396
# Epoch 15/10000
# 239/239 [==============================] - 41s 169ms/step - loss: 0.2954 - accuracy: 0.9268 - Top3: 0.9858 - val_loss: 0.9119 - val_accuracy: 0.8113 - val_Top3: 0.9208
# Epoch 16/10000
# 239/239 [==============================] - 40s 166ms/step - loss: 0.2182 - accuracy: 0.9425 - Top3: 0.9904 - val_loss: 0.8304 - val_accuracy: 0.7962 - val_Top3: 0.9170
# Epoch 17/10000
# 239/239 [==============================] - 41s 170ms/step - loss: 0.2217 - accuracy: 0.9401 - Top3: 0.9898 - val_loss: 0.8894 - val_accuracy: 0.8264 - val_Top3: 0.9019
# Epoch 18/10000
# 239/239 [==============================] - 38s 156ms/step - loss: 0.2022 - accuracy: 0.9473 - Top3: 0.9908 - val_loss: 0.7038 - val_accuracy: 0.8226 - val_Top3: 0.9396
# Epoch 19/10000
# 239/239 [==============================] - 36s 148ms/step - loss: 0.1769 - accuracy: 0.9551 - Top3: 0.9925 - val_loss: 0.9334 - val_accuracy: 0.8151 - val_Top3: 0.9283
# Epoch 20/10000
# 239/239 [==============================] - 39s 164ms/step - loss: 0.1931 - accuracy: 0.9511 - Top3: 0.9924 - val_loss: 1.0408 - val_accuracy: 0.8302 - val_Top3: 0.9132
# Epoch 21/10000
# 239/239 [==============================] - 37s 155ms/step - loss: 0.2037 - accuracy: 0.9485 - Top3: 0.9930 - val_loss: 1.0861 - val_accuracy: 0.8264 - val_Top3: 0.9057
# Epoch 22/10000
# 239/239 [==============================] - 37s 156ms/step - loss: 0.2104 - accuracy: 0.9473 - Top3: 0.9912 - val_loss: 0.9212 - val_accuracy: 0.8302 - val_Top3: 0.9132
# Epoch 22: early stopping

# %%
plot_model(
    model6,
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
)

# %%
model6.evaluate(test)
# Out:
# 9/9 [==============================] - 1s 48ms/step - loss: 1.2295 - accuracy: 0.7962 - Top3: 0.9132
# [1.22952401638031, 0.796226441860199, 0.9132075309753418]

# %%
plt.plot(history6.history['accuracy'], label='Training Accuracy')
plt.plot(history6.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Modelo 1')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
model6.save_weights(input('Nombre: ')+'.h5', overwrite=True)
