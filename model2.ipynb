# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import pandas as pd
from keras.utils import image_dataset_from_directory, plot_model
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, AveragePooling2D, Dropout, Flatten
from keras.metrics import SparseTopKCategoricalAccuracy
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
img_dims = (256, 256)
batch_size = 32
n_inputs = img_dims[0] * img_dims[1] * 3

train = image_dataset_from_directory(
    directory='cards/train',
    image_size=img_dims,
    batch_size=batch_size
)

val = image_dataset_from_directory(
    directory='cards/valid',
    image_size=img_dims,
    batch_size=batch_size
)

test = image_dataset_from_directory(
    directory='cards/test',
    image_size=img_dims,
    batch_size=batch_size
)
# Out:
# Found 7624 files belonging to 53 classes.
# Found 265 files belonging to 53 classes.
# Found 265 files belonging to 53 classes.

# %%
model2 = Sequential()


model2.add(Conv2D(
    filters=32,                     
    kernel_size=(3, 3),             
    activation='relu',              
    input_shape=img_dims + (3,),
    data_format="channels_last"
))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(
    filters=32,                     
    kernel_size=(3, 3),             
    activation='relu',              
    use_bias=True                   
))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(rate=0.2))


model2.add(Conv2D(
    filters=64, 
    kernel_size=(3, 3),
    activation='relu',
    use_bias=True
))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(rate=0.2))


model2.add(Conv2D(
    filters=128, 
    kernel_size=(3, 3),
    activation='relu',
    use_bias=True
))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(rate=0.2))


model2.add(Conv2D(
    filters=512, 
    kernel_size=(3, 3),
    activation='relu',
    use_bias=True
))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(rate=0.2))


model2.add(Conv2D(
    filters=1024, 
    kernel_size=(3, 3),
    activation='relu',
    use_bias=True
))
model2.add(AveragePooling2D(pool_size=(1, 1)))

model2.add(Conv2D(
    filters=512, 
    kernel_size=(3, 3),
    activation='relu',
    use_bias=True
))
model2.add(MaxPooling2D(pool_size=(2, 2)))


model2.add(Flatten())

model2.add(Dense(1024, activation='relu'))
model2.add(Dense(512, activation='relu'))
model2.add(Dense(128, activation='relu'))
model2.add(Dense(53, activation='softmax'))

model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 62, 62, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 512)       590336
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 1024)        4719616
#
#  average_pooling2d (AverageP  (None, 4, 4, 1024)       0
#  ooling2D)
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 512)         4719104
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  dense_3 (Dense)             (None, 53)                6837
#
# =================================================================
# Total params: 11,254,165
# Trainable params: 11,254,165
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', SparseTopKCategoricalAccuracy(k=3, name = 'Top3')]
)

callbacks = [
    EarlyStopping(
        monitor="accuracy",
        min_delta=1e-4,
        patience=3,
        verbose=1,
    )
]

history2 = model2.fit(
    train,
    validation_data = val,
    epochs = 10000,
    callbacks = callbacks
)
# Out:
# Epoch 1/10000
# 239/239 [==============================] - 70s 263ms/step - loss: 4.9912 - accuracy: 0.0312 - Top3: 0.0876 - val_loss: 3.6781 - val_accuracy: 0.0415 - val_Top3: 0.1245
# Epoch 2/10000
# 239/239 [==============================] - 20s 83ms/step - loss: 3.3054 - accuracy: 0.1268 - Top3: 0.2796 - val_loss: 2.4776 - val_accuracy: 0.2868 - val_Top3: 0.6151
# Epoch 3/10000
# 239/239 [==============================] - 20s 83ms/step - loss: 2.3998 - accuracy: 0.2825 - Top3: 0.5720 - val_loss: 1.8986 - val_accuracy: 0.3736 - val_Top3: 0.6981
# Epoch 4/10000
# 239/239 [==============================] - 20s 83ms/step - loss: 2.1066 - accuracy: 0.3417 - Top3: 0.6427 - val_loss: 1.7495 - val_accuracy: 0.4415 - val_Top3: 0.7509
# Epoch 5/10000
# 239/239 [==============================] - 20s 83ms/step - loss: 1.8999 - accuracy: 0.4096 - Top3: 0.6750 - val_loss: 1.3875 - val_accuracy: 0.5358 - val_Top3: 0.7849
# Epoch 6/10000
# 239/239 [==============================] - 20s 83ms/step - loss: 1.6759 - accuracy: 0.4987 - Top3: 0.7217 - val_loss: 1.2012 - val_accuracy: 0.6000 - val_Top3: 0.8075
# Epoch 7/10000
# 239/239 [==============================] - 20s 83ms/step - loss: 1.5046 - accuracy: 0.5539 - Top3: 0.7572 - val_loss: 1.0229 - val_accuracy: 0.7019 - val_Top3: 0.8528
# Epoch 8/10000
# 239/239 [==============================] - 20s 83ms/step - loss: 1.4029 - accuracy: 0.5901 - Top3: 0.7769 - val_loss: 1.0733 - val_accuracy: 0.6679 - val_Top3: 0.8642
# Epoch 9/10000
# 239/239 [==============================] - 21s 88ms/step - loss: 1.2605 - accuracy: 0.6334 - Top3: 0.7985 - val_loss: 0.9437 - val_accuracy: 0.7019 - val_Top3: 0.8679
# Epoch 10/10000
# 239/239 [==============================] - 23s 95ms/step - loss: 1.2068 - accuracy: 0.6529 - Top3: 0.8109 - val_loss: 0.9613 - val_accuracy: 0.7245 - val_Top3: 0.8604
# Epoch 11/10000
# 239/239 [==============================] - 23s 95ms/step - loss: 1.1161 - accuracy: 0.6746 - Top3: 0.8292 - val_loss: 0.8786 - val_accuracy: 0.7472 - val_Top3: 0.8755
# Epoch 12/10000
# 239/239 [==============================] - 23s 95ms/step - loss: 1.0305 - accuracy: 0.7009 - Top3: 0.8418 - val_loss: 0.7909 - val_accuracy: 0.7547 - val_Top3: 0.8943
# Epoch 13/10000
# 239/239 [==============================] - 23s 94ms/step - loss: 0.9746 - accuracy: 0.7137 - Top3: 0.8528 - val_loss: 0.7745 - val_accuracy: 0.7887 - val_Top3: 0.8868
# Epoch 14/10000
# 239/239 [==============================] - 23s 95ms/step - loss: 0.9598 - accuracy: 0.7230 - Top3: 0.8570 - val_loss: 0.8571 - val_accuracy: 0.7660 - val_Top3: 0.8755
# Epoch 15/10000
# Epoch 31/10000
# 239/239 [==============================] - 22s 93ms/step - loss: 0.4856 - accuracy: 0.8649 - Top3: 0.9500 - val_loss: 1.0159 - val_accuracy: 0.8000 - val_Top3: 0.8717
# Epoch 32/10000
# 239/239 [==============================] - 23s 95ms/step - loss: 0.4682 - accuracy: 0.8633 - Top3: 0.9499 - val_loss: 1.1598 - val_accuracy: 0.7925 - val_Top3: 0.8755
# Epoch 33/10000
# 239/239 [==============================] - 23s 93ms/step - loss: 0.4525 - accuracy: 0.8738 - Top3: 0.9555 - val_loss: 0.9666 - val_accuracy: 0.8038 - val_Top3: 0.8868
# Epoch 34/10000
# 239/239 [==============================] - 22s 92ms/step - loss: 0.4673 - accuracy: 0.8679 - Top3: 0.9542 - val_loss: 0.8345 - val_accuracy: 0.8075 - val_Top3: 0.9132
# Epoch 35/10000
# 239/239 [==============================] - 22s 92ms/step - loss: 0.4292 - accuracy: 0.8823 - Top3: 0.9599 - val_loss: 0.9842 - val_accuracy: 0.8189 - val_Top3: 0.8981
# Epoch 36/10000
# 239/239 [==============================] - 22s 92ms/step - loss: 0.4371 - accuracy: 0.8785 - Top3: 0.9593 - val_loss: 1.1692 - val_accuracy: 0.7962 - val_Top3: 0.8981
# Epoch 37/10000
# 239/239 [==============================] - 22s 93ms/step - loss: 0.4114 - accuracy: 0.8850 - Top3: 0.9630 - val_loss: 0.9308 - val_accuracy: 0.7811 - val_Top3: 0.9019
# Epoch 38/10000
# 239/239 [==============================] - 22s 92ms/step - loss: 0.3885 - accuracy: 0.8903 - Top3: 0.9666 - val_loss: 1.1292 - val_accuracy: 0.7887 - val_Top3: 0.8943
# Epoch 39/10000
# 239/239 [==============================] - 22s 92ms/step - loss: 0.3459 - accuracy: 0.8991 - Top3: 0.9680 - val_loss: 1.2887 - val_accuracy: 0.7774 - val_Top3: 0.8830
# Epoch 40/10000
# 239/239 [==============================] - 22s 91ms/step - loss: 0.3527 - accuracy: 0.9061 - Top3: 0.9723 - val_loss: 0.8408 - val_accuracy: 0.8113 - val_Top3: 0.9019
# Epoch 41/10000
# 239/239 [==============================] - 22s 91ms/step - loss: 0.3890 - accuracy: 0.8994 - Top3: 0.9654 - val_loss: 0.7931 - val_accuracy: 0.8075 - val_Top3: 0.8981
# Epoch 42/10000
# 239/239 [==============================] - 22s 92ms/step - loss: 0.3793 - accuracy: 0.8981 - Top3: 0.9675 - val_loss: 1.1088 - val_accuracy: 0.7887 - val_Top3: 0.8868
# Epoch 43/10000
# 239/239 [==============================] - 24s 101ms/step - loss: 0.3486 - accuracy: 0.9052 - Top3: 0.9731 - val_loss: 1.0386 - val_accuracy: 0.8000 - val_Top3: 0.8642
# Epoch 43: early stopping

# %%
plot_model(
    model2,
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
)

# %%
model2.evaluate(test)
# Out:
# 9/9 [==============================] - 1s 33ms/step - loss: 1.2070 - accuracy: 0.7849 - Top3: 0.8604
# [1.206978440284729, 0.7849056720733643, 0.8603773713111877]

# %%
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Modelo 2')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
model2.save_weights(input('Nombre: ')+'.h5', overwrite=True)
