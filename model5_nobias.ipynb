# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import pandas as pd
from keras.utils import image_dataset_from_directory, plot_model
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, AveragePooling2D, Dropout, Flatten
from keras.metrics import SparseTopKCategoricalAccuracy
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
img_dims = (256, 256)
batch_size = 32
n_inputs = img_dims[0] * img_dims[1] * 3

train = image_dataset_from_directory(
    directory='cards/train',
    image_size=img_dims,
    batch_size=batch_size
)

val = image_dataset_from_directory(
    directory='cards/valid',
    image_size=img_dims,
    batch_size=batch_size
)

test = image_dataset_from_directory(
    directory='cards/test',
    image_size=img_dims,
    batch_size=batch_size
)
# Out:
# Found 7624 files belonging to 53 classes.
# Found 265 files belonging to 53 classes.
# Found 265 files belonging to 53 classes.

# %%
model5 = Sequential()


model5.add(Conv2D(
    filters=32,
    kernel_size=(3, 3),
    activation='relu',
    input_shape=img_dims + (3,),
    data_format="channels_last"
))


model5.add(Conv2D(
    filters=32,
    kernel_size=(3, 3),
    activation='relu'
))
model5.add(MaxPooling2D(pool_size=(2, 2)))
model5.add(Dropout(rate=0.2))


model5.add(Conv2D(
    filters=64, 
    kernel_size=(3, 3),
    activation='relu'
))
model5.add(MaxPooling2D(pool_size=(3, 3)))
model5.add(Dropout(rate=0.2))


model5.add(Conv2D(
    filters=128, 
    kernel_size=(3, 3),
    activation='relu'
))
model5.add(MaxPooling2D(pool_size=(4, 4)))
model5.add(Dropout(rate=0.2))


model5.add(Flatten())
model5.add(Dense(512, activation='relu'))
model5.add(Dense(128, activation='relu'))
model5.add(Dense(53, activation='softmax'))

model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 252, 252, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 126, 126, 32)     0
#  )
#
#  dropout (Dropout)           (None, 126, 126, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 124, 124, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 41, 41, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 41, 41, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 39, 39, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 9, 9, 128)         0
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 512)               5308928
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 53)                6837
#
# =================================================================
# Total params: 5,483,925
# Trainable params: 5,483,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', SparseTopKCategoricalAccuracy(k=3, name = 'Top3')]
)

callbacks = [
    EarlyStopping(
        monitor="accuracy",
        min_delta=1e-4,
        patience=3,
        verbose=1,
    )
]

history5 = model5.fit(
    train,
    validation_data = val,
    epochs = 10000,
    callbacks = callbacks
)
# Out:
# Epoch 1/10000
# 239/239 [==============================] - 81s 293ms/step - loss: 7.6870 - accuracy: 0.1546 - Top3: 0.3009 - val_loss: 2.5035 - val_accuracy: 0.3321 - val_Top3: 0.5887
# Epoch 2/10000
# 239/239 [==============================] - 26s 107ms/step - loss: 2.0365 - accuracy: 0.4437 - Top3: 0.6637 - val_loss: 1.4755 - val_accuracy: 0.5849 - val_Top3: 0.7887
# Epoch 3/10000
# 239/239 [==============================] - 26s 110ms/step - loss: 1.4833 - accuracy: 0.5921 - Top3: 0.7723 - val_loss: 1.2788 - val_accuracy: 0.6453 - val_Top3: 0.8528
# Epoch 4/10000
# 239/239 [==============================] - 28s 116ms/step - loss: 1.1387 - accuracy: 0.6801 - Top3: 0.8395 - val_loss: 0.9657 - val_accuracy: 0.7094 - val_Top3: 0.8679
# Epoch 5/10000
# 239/239 [==============================] - 26s 107ms/step - loss: 0.8754 - accuracy: 0.7500 - Top3: 0.8917 - val_loss: 1.0344 - val_accuracy: 0.7057 - val_Top3: 0.8528
# Epoch 6/10000
# 239/239 [==============================] - 28s 115ms/step - loss: 0.6908 - accuracy: 0.7977 - Top3: 0.9233 - val_loss: 0.9917 - val_accuracy: 0.7434 - val_Top3: 0.8642
# Epoch 7/10000
# 239/239 [==============================] - 26s 107ms/step - loss: 0.5644 - accuracy: 0.8315 - Top3: 0.9453 - val_loss: 1.1306 - val_accuracy: 0.7396 - val_Top3: 0.8528
# Epoch 8/10000
# 239/239 [==============================] - 27s 111ms/step - loss: 0.4421 - accuracy: 0.8708 - Top3: 0.9679 - val_loss: 1.1392 - val_accuracy: 0.7774 - val_Top3: 0.8906
# Epoch 9/10000
# 239/239 [==============================] - 29s 121ms/step - loss: 0.3965 - accuracy: 0.8877 - Top3: 0.9746 - val_loss: 1.1193 - val_accuracy: 0.7660 - val_Top3: 0.8830
# Epoch 10/10000
# 239/239 [==============================] - 29s 120ms/step - loss: 0.3293 - accuracy: 0.9066 - Top3: 0.9798 - val_loss: 1.0888 - val_accuracy: 0.7849 - val_Top3: 0.8755
# Epoch 11/10000
# 239/239 [==============================] - 30s 124ms/step - loss: 0.2837 - accuracy: 0.9230 - Top3: 0.9864 - val_loss: 1.2132 - val_accuracy: 0.7736 - val_Top3: 0.8642
# Epoch 12/10000
# 239/239 [==============================] - 31s 127ms/step - loss: 0.2483 - accuracy: 0.9326 - Top3: 0.9887 - val_loss: 1.2394 - val_accuracy: 0.7472 - val_Top3: 0.8717
# Epoch 13/10000
# 239/239 [==============================] - 30s 123ms/step - loss: 0.2335 - accuracy: 0.9374 - Top3: 0.9920 - val_loss: 0.9799 - val_accuracy: 0.8038 - val_Top3: 0.8717
# Epoch 14/10000
# 239/239 [==============================] - 30s 124ms/step - loss: 0.2181 - accuracy: 0.9401 - Top3: 0.9907 - val_loss: 1.2406 - val_accuracy: 0.7660 - val_Top3: 0.8792
# Epoch 15/10000
# 239/239 [==============================] - 31s 127ms/step - loss: 0.1987 - accuracy: 0.9449 - Top3: 0.9919 - val_loss: 1.3143 - val_accuracy: 0.7887 - val_Top3: 0.8792
# Epoch 16/10000
# 239/239 [==============================] - 29s 123ms/step - loss: 0.1665 - accuracy: 0.9547 - Top3: 0.9937 - val_loss: 1.2403 - val_accuracy: 0.8000 - val_Top3: 0.8943
# Epoch 17/10000
# 239/239 [==============================] - 29s 122ms/step - loss: 0.1619 - accuracy: 0.9562 - Top3: 0.9955 - val_loss: 1.1385 - val_accuracy: 0.8075 - val_Top3: 0.9057
# Epoch 18/10000
# 239/239 [==============================] - 29s 122ms/step - loss: 0.1710 - accuracy: 0.9529 - Top3: 0.9945 - val_loss: 1.3073 - val_accuracy: 0.7962 - val_Top3: 0.8717
# Epoch 19/10000
# 239/239 [==============================] - 29s 122ms/step - loss: 0.1720 - accuracy: 0.9583 - Top3: 0.9936 - val_loss: 1.1355 - val_accuracy: 0.7962 - val_Top3: 0.8943
# Epoch 20/10000
# 239/239 [==============================] - 30s 125ms/step - loss: 0.1433 - accuracy: 0.9663 - Top3: 0.9953 - val_loss: 1.1387 - val_accuracy: 0.7962 - val_Top3: 0.8792
# Epoch 21/10000
# 239/239 [==============================] - 29s 121ms/step - loss: 0.1410 - accuracy: 0.9610 - Top3: 0.9958 - val_loss: 1.1655 - val_accuracy: 0.7962 - val_Top3: 0.8755
# Epoch 22/10000
# 239/239 [==============================] - 29s 121ms/step - loss: 0.1334 - accuracy: 0.9673 - Top3: 0.9962 - val_loss: 1.0912 - val_accuracy: 0.8189 - val_Top3: 0.9057
# Epoch 23/10000
# 239/239 [==============================] - 29s 122ms/step - loss: 0.1402 - accuracy: 0.9630 - Top3: 0.9958 - val_loss: 1.0396 - val_accuracy: 0.7962 - val_Top3: 0.8830
# Epoch 24/10000
# 239/239 [==============================] - 30s 124ms/step - loss: 0.1458 - accuracy: 0.9618 - Top3: 0.9957 - val_loss: 1.6063 - val_accuracy: 0.7736 - val_Top3: 0.8755
# Epoch 25/10000
# 239/239 [==============================] - 30s 126ms/step - loss: 0.1601 - accuracy: 0.9580 - Top3: 0.9946 - val_loss: 1.4822 - val_accuracy: 0.7698 - val_Top3: 0.8679
# Epoch 25: early stopping

# %%
plot_model(
    model5,
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
)

# %%
model5.evaluate(test)
# Out:
# 9/9 [==============================] - 1s 41ms/step - loss: 1.6315 - accuracy: 0.7811 - Top3: 0.8642
# [1.631514072418213, 0.7811321020126343, 0.8641509413719177]

# %%
plt.plot(history5.history['accuracy'], label='Training Accuracy')
plt.plot(history5.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Modelo 1')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
model5.save_weights(input('Nombre: ')+'.h5', overwrite=True)
